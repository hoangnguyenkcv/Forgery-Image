# %%
import keras
from keras.models import Sequential
from keras import backend as K
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.optimizers import SGD, RMSprop, Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.normalization import  BatchNormalization
from keras.layers.convolutional import *
import numpy as np
import tensorflow as tf
#import theano
import  matplotlib.pyplot as plt
import matplotlib
import itertools
from numpy import*
from sklearn.utils import shuffle
# %matplotlib inline
import random as rn
import os
os.environ['PYTHONASHSEED']= '0'
# Out:
# Using TensorFlow backend.

# %%
#setting  the  seed for nummy_gennerated random numbers
np.random.seed(45)
#seting the seed for python random numbers
rn.seed(124)
#seting the seed for tensorflow random numbers
tf.set_random_seed(98)

# %%
# Force  tensorflow  to use  a  single  thread
sess = tf.Session(graph = tf.get_default_graph(), config = tf.ConfigProto(log_device_placement=True))
K.set_session(sess)

# %%
train_path = 'D:\CASIA_DATASET\CASIA1\Train' 
valid_path = 'D:\CASIA_DATASET\CASIA1\Valid' 
test_path = 'D:\CASIA_DATASET\CASIA1\Test'

# %%
# train_datagen = ImageDataGenerator(
#         shear_range=0.2,
#         zoom_range=0.2,
#         horizontal_flip=True)

# test_datagen = ImageDataGenerator()
                                  

# train_generator = train_datagen.flow_from_directory(
#         '../Data/Train',  
#         batch_size=batch_size,
#         shuffle=True,
#         target_size=input_size[1:],
#         class_mode='categorical')  

# validation_generator = test_datagen.flow_from_directory(
#         '../Data/Test',  
#         batch_size=batch_size,
#         target_size=input_size[1:],
#         shuffle=True,
#         class_mode='categorical')

# %%
train_batches = ImageDataGenerator().flow_from_directory(train_path, target_size = (224,224), classes = ['Au','Sp'], batch_size =10)
valid_batches = ImageDataGenerator().flow_from_directory(valid_path, target_size = (224,224), classes = ['Au','Sp'], batch_size = 10)
test_batches = ImageDataGenerator().flow_from_directory(test_path, target_size = (224,224), classes = ['Au','Sp'], batch_size =10)
# Out:
# Found 1201 images belonging to 2 classes.
# Found 260 images belonging to 2 classes.
# Found 260 images belonging to 2 classes.

# %%
# plots images with labels  within jupyter notebook

def plots(ims, figsize = (12,6), rows=1, interp =False , titles = None):
    if  type(ims[0]) is  np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] !=3):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize = figsize) 
    cols = len(ims)// rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(len(ims)):
        sp = f.add_subplot(rows,cols,i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(titles[i], fontsize=16)
        plt.imshow(ims[i], interpolation = None if interp else 'none')
        plt.show()

# %%
imgs, labels = next(train_batches)

# %%
plots(imgs, titles = labels)

# %%
####  Build Fine-tuned VGG16 model
vgg16_model = keras.applications.vgg16.VGG16()
#vgg16_model.summary()

# %%
model = Sequential()
for layer in vgg16_model.layers:
    model.add(layer)

# %%
model.layers.pop()

# %%
#for layer in model.layers:
#    layer.trainable = False

# %%
### add SVM in the  last layer
from keras import regularizers
model.add(Dense(2, 
                kernel_regularizer=regularizers.l2(0.01),))
model.add(Activation('linear'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 2002
# _________________________________________________________________
# activation_1 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 134,262,546
# Trainable params: 134,262,546
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model.compile(Adam(lr=0.0001), loss='categorical_crossentropy', metrics = ['accuracy'])

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='hinge', optimizer=sgd, metrics=['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint
# Save check point
filepath = "weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose =1, save_best_only = True, mode ='max')
callbacks_list= [checkpoint]
 # Fit the model
# model.fit(X,Y, validation_split=0.33, nb_epoch =150, batch_size =10, callbacks = callbacks_list, verbose =0)

history = model.fit_generator(train_batches, steps_per_epoch = 120, validation_data = valid_batches, validation_steps=26, epochs =100, callbacks = callbacks_list, verbose =2)
# Out:
# Epoch 1/100
#  - 32s - loss: 0.9463 - acc: 0.5108 - val_loss: 0.8130 - val_acc: 0.5385
#
# Epoch 00001: val_acc improved from -inf to 0.53846, saving model to weights.best.hdf5
# Epoch 2/100
#  - 29s - loss: 0.6671 - acc: 0.5350 - val_loss: 0.5413 - val_acc: 0.5385
#
# Epoch 00002: val_acc did not improve
# Epoch 3/100
#  - 29s - loss: 0.5396 - acc: 0.5367 - val_loss: 0.5387 - val_acc: 0.5385
#
# Epoch 00003: val_acc did not improve
# Epoch 4/100
#  - 29s - loss: 0.5378 - acc: 0.5366 - val_loss: 0.5369 - val_acc: 0.5385
#
# Epoch 00004: val_acc did not improve
# Epoch 5/100
#  - 29s - loss: 0.5360 - acc: 0.5375 - val_loss: 0.5351 - val_acc: 0.5385
#
# Epoch 00005: val_acc improved from 0.53846 to 0.53846, saving model to weights.best.hdf5
# Epoch 6/100
#  - 29s - loss: 0.5343 - acc: 0.5300 - val_loss: 0.5335 - val_acc: 0.5385
#
# Epoch 00006: val_acc did not improve
# Epoch 7/100
#  - 29s - loss: 0.5328 - acc: 0.4809 - val_loss: 0.5320 - val_acc: 0.4615
#
# Epoch 00007: val_acc did not improve
# Epoch 8/100
#  - 29s - loss: 0.5313 - acc: 0.5116 - val_loss: 0.5306 - val_acc: 0.4615
#
# Epoch 00008: val_acc did not improve
# Epoch 9/100
#  - 29s - loss: 0.5299 - acc: 0.4966 - val_loss: 0.5293 - val_acc: 0.5385
#
# Epoch 00009: val_acc did not improve
# Epoch 10/100
#  - 29s - loss: 0.5286 - acc: 0.5367 - val_loss: 0.5280 - val_acc: 0.4615
#
# Epoch 00010: val_acc did not improve
# Epoch 11/100
#  - 29s - loss: 0.5273 - acc: 0.5158 - val_loss: 0.5267 - val_acc: 0.5385
#
# Epoch 00011: val_acc did not improve
# Epoch 12/100
#  - 29s - loss: 0.5261 - acc: 0.4792 - val_loss: 0.5255 - val_acc: 0.5385
#
# Epoch 00012: val_acc did not improve
# Epoch 13/100
#  - 29s - loss: 0.5250 - acc: 0.4833 - val_loss: 0.5244 - val_acc: 0.5385
#
# Epoch 00013: val_acc did not improve
# Epoch 14/100
#  - 29s - loss: 0.5239 - acc: 0.4950 - val_loss: 0.5233 - val_acc: 0.5385
#
# Epoch 00014: val_acc did not improve
# Epoch 15/100
#  - 29s - loss: 0.5228 - acc: 0.4891 - val_loss: 0.5223 - val_acc: 0.4615
#
# Epoch 00015: val_acc did not improve
# Epoch 16/100
#  - 29s - loss: 0.5218 - acc: 0.4958 - val_loss: 0.5213 - val_acc: 0.5385
#
# Epoch 00016: val_acc did not improve
# Epoch 17/100
#  - 29s - loss: 0.5209 - acc: 0.5124 - val_loss: 0.5204 - val_acc: 0.4615
#
# Epoch 00017: val_acc did not improve
# Epoch 18/100
#  - 29s - loss: 0.5200 - acc: 0.4825 - val_loss: 0.5195 - val_acc: 0.5385
#
# Epoch 00018: val_acc did not improve
# Epoch 19/100
#  - 29s - loss: 0.5191 - acc: 0.4792 - val_loss: 0.5187 - val_acc: 0.5385
#
# Epoch 00019: val_acc did not improve
# Epoch 20/100
#  - 29s - loss: 0.5183 - acc: 0.5284 - val_loss: 0.5179 - val_acc: 0.4615
#
# Epoch 00020: val_acc did not improve
# Epoch 21/100
#  - 29s - loss: 0.5175 - acc: 0.4759 - val_loss: 0.5171 - val_acc: 0.4615
#
# Epoch 00021: val_acc did not improve
# Epoch 22/100
#  - 29s - loss: 0.5167 - acc: 0.5458 - val_loss: 0.5163 - val_acc: 0.4615
#
# Epoch 00022: val_acc did not improve
# Epoch 23/100
#  - 29s - loss: 0.5160 - acc: 0.4817 - val_loss: 0.5156 - val_acc: 0.4615
#
# Epoch 00023: val_acc did not improve
# Epoch 24/100
#  - 29s - loss: 0.5153 - acc: 0.5184 - val_loss: 0.5149 - val_acc: 0.5385
#
# Epoch 00024: val_acc did not improve
# Epoch 25/100
#  - 29s - loss: 0.5146 - acc: 0.4792 - val_loss: 0.5143 - val_acc: 0.5385
#
# Epoch 00025: val_acc did not improve
# Epoch 26/100
#  - 29s - loss: 0.5140 - acc: 0.5292 - val_loss: 0.5137 - val_acc: 0.4615
#
# Epoch 00026: val_acc did not improve
# Epoch 27/100
#  - 29s - loss: 0.5134 - acc: 0.5017 - val_loss: 0.5131 - val_acc: 0.5385
#
# Epoch 00027: val_acc did not improve
# Epoch 28/100
#  - 29s - loss: 0.5128 - acc: 0.5166 - val_loss: 0.5125 - val_acc: 0.5385
#
# Epoch 00028: val_acc did not improve
# Epoch 29/100
#  - 29s - loss: 0.5123 - acc: 0.5208 - val_loss: 0.5120 - val_acc: 0.5385
#
# Epoch 00029: val_acc did not improve
# Epoch 30/100
#  - 29s - loss: 0.5117 - acc: 0.4942 - val_loss: 0.5115 - val_acc: 0.4615
#
# Epoch 00030: val_acc did not improve
# Epoch 31/100
#  - 29s - loss: 0.5112 - acc: 0.5158 - val_loss: 0.5110 - val_acc: 0.5385
#
# Epoch 00031: val_acc did not improve
# Epoch 32/100
#  - 29s - loss: 0.5108 - acc: 0.5067 - val_loss: 0.5105 - val_acc: 0.5385
#
# Epoch 00032: val_acc did not improve
# Epoch 33/100
#  - 29s - loss: 0.5103 - acc: 0.5134 - val_loss: 0.5101 - val_acc: 0.4615
#
# Epoch 00033: val_acc did not improve
# Epoch 34/100
#  - 29s - loss: 0.5099 - acc: 0.5091 - val_loss: 0.5097 - val_acc: 0.5385
#
# Epoch 00034: val_acc did not improve
# Epoch 35/100
#  - 29s - loss: 0.5094 - acc: 0.5158 - val_loss: 0.5092 - val_acc: 0.5385
#
# Epoch 00035: val_acc did not improve
# Epoch 36/100
#  - 29s - loss: 0.5090 - acc: 0.5117 - val_loss: 0.5089 - val_acc: 0.5385
#
# Epoch 00036: val_acc did not improve
# Epoch 37/100
#  - 29s - loss: 0.5087 - acc: 0.4942 - val_loss: 0.5085 - val_acc: 0.5385
#
# Epoch 00037: val_acc did not improve
# Epoch 38/100
#  - 29s - loss: 0.5083 - acc: 0.5191 - val_loss: 0.5081 - val_acc: 0.5385
#
# Epoch 00038: val_acc did not improve
# Epoch 39/100
#  - 29s - loss: 0.5079 - acc: 0.4958 - val_loss: 0.5078 - val_acc: 0.4615
#
# Epoch 00039: val_acc did not improve
# Epoch 40/100
#  - 29s - loss: 0.5076 - acc: 0.4908 - val_loss: 0.5075 - val_acc: 0.4615
#
# Epoch 00040: val_acc did not improve
# Epoch 41/100
#  - 29s - loss: 0.5073 - acc: 0.5100 - val_loss: 0.5071 - val_acc: 0.5385
#
# Epoch 00041: val_acc did not improve
# Epoch 42/100
#  - 29s - loss: 0.5070 - acc: 0.4925 - val_loss: 0.5068 - val_acc: 0.4615
#
# Epoch 00042: val_acc did not improve
# Epoch 43/100
#  - 29s - loss: 0.5067 - acc: 0.5108 - val_loss: 0.5065 - val_acc: 0.4615
#
# Epoch 00043: val_acc did not improve
# Epoch 44/100
#  - 29s - loss: 0.5064 - acc: 0.5217 - val_loss: 0.5063 - val_acc: 0.4615
#
# Epoch 00044: val_acc did not improve
# Epoch 45/100
#  - 29s - loss: 0.5062 - acc: 0.5158 - val_loss: 0.5060 - val_acc: 0.5385
#
# Epoch 00045: val_acc did not improve
# Epoch 46/100
#  - 29s - loss: 0.5059 - acc: 0.5108 - val_loss: 0.5058 - val_acc: 0.4615
#
# Epoch 00046: val_acc did not improve
# Epoch 47/100
#  - 29s - loss: 0.5057 - acc: 0.4741 - val_loss: 0.5055 - val_acc: 0.4615
#
# Epoch 00047: val_acc did not improve
# Epoch 48/100
#  - 29s - loss: 0.5054 - acc: 0.4933 - val_loss: 0.5053 - val_acc: 0.5385
#
# Epoch 00048: val_acc did not improve
# Epoch 49/100
#  - 29s - loss: 0.5052 - acc: 0.5125 - val_loss: 0.5051 - val_acc: 0.5385
#
# Epoch 00049: val_acc did not improve
# Epoch 50/100
#  - 29s - loss: 0.5050 - acc: 0.5117 - val_loss: 0.5049 - val_acc: 0.5385
#
# Epoch 00050: val_acc improved from 0.53846 to 0.53846, saving model to weights.best.hdf5
# Epoch 51/100
#  - 29s - loss: 0.5048 - acc: 0.5108 - val_loss: 0.5047 - val_acc: 0.5385
#
# Epoch 00051: val_acc did not improve
# Epoch 52/100
#  - 29s - loss: 0.5046 - acc: 0.5183 - val_loss: 0.5045 - val_acc: 0.5385
#
# Epoch 00052: val_acc did not improve
# Epoch 53/100
#  - 29s - loss: 0.5044 - acc: 0.5091 - val_loss: 0.5043 - val_acc: 0.5385
#
# Epoch 00053: val_acc did not improve
# Epoch 54/100
#  - 29s - loss: 0.5042 - acc: 0.4742 - val_loss: 0.5041 - val_acc: 0.4615
#
# Epoch 00054: val_acc did not improve
# Epoch 55/100
#  - 29s - loss: 0.5041 - acc: 0.5158 - val_loss: 0.5040 - val_acc: 0.5385
#
# Epoch 00055: val_acc did not improve
# Epoch 56/100
#  - 29s - loss: 0.5039 - acc: 0.4900 - val_loss: 0.5038 - val_acc: 0.4615
#
# Epoch 00056: val_acc did not improve
# Epoch 57/100
#  - 29s - loss: 0.5037 - acc: 0.5058 - val_loss: 0.5037 - val_acc: 0.4615
#
# Epoch 00057: val_acc did not improve
# Epoch 58/100
#  - 29s - loss: 0.5036 - acc: 0.4942 - val_loss: 0.5035 - val_acc: 0.4615
#
# Epoch 00058: val_acc did not improve
# Epoch 59/100
#  - 29s - loss: 0.5034 - acc: 0.4458 - val_loss: 0.5034 - val_acc: 0.4615
#
# Epoch 00059: val_acc did not improve
# Epoch 60/100
#  - 29s - loss: 0.5033 - acc: 0.5016 - val_loss: 0.5032 - val_acc: 0.5385
#
# Epoch 00060: val_acc did not improve
# Epoch 61/100
#  - 29s - loss: 0.5032 - acc: 0.5200 - val_loss: 0.5031 - val_acc: 0.5385
#
# Epoch 00061: val_acc did not improve
# Epoch 62/100
#  - 29s - loss: 0.5030 - acc: 0.5024 - val_loss: 0.5030 - val_acc: 0.4615
#
# Epoch 00062: val_acc did not improve
# Epoch 63/100
#  - 29s - loss: 0.5029 - acc: 0.5308 - val_loss: 0.5029 - val_acc: 0.5385
#
# Epoch 00063: val_acc did not improve
# Epoch 64/100
#  - 29s - loss: 0.5028 - acc: 0.4975 - val_loss: 0.5028 - val_acc: 0.4615
#
# Epoch 00064: val_acc did not improve
# Epoch 65/100
#  - 29s - loss: 0.5027 - acc: 0.4933 - val_loss: 0.5027 - val_acc: 0.5385
#
# Epoch 00065: val_acc did not improve
# Epoch 66/100
#  - 29s - loss: 0.5026 - acc: 0.5466 - val_loss: 0.5025 - val_acc: 0.5385
#
# Epoch 00066: val_acc did not improve
# Epoch 67/100
#  - 29s - loss: 0.5025 - acc: 0.5000 - val_loss: 0.5024 - val_acc: 0.5385
#
# Epoch 00067: val_acc did not improve
# Epoch 68/100
#  - 29s - loss: 0.5024 - acc: 0.5025 - val_loss: 0.5024 - val_acc: 0.5385
#
# Epoch 00068: val_acc did not improve
# Epoch 69/100
#  - 29s - loss: 0.5023 - acc: 0.5209 - val_loss: 0.5023 - val_acc: 0.4615
#
# Epoch 00069: val_acc did not improve
# Epoch 70/100
#  - 29s - loss: 0.5022 - acc: 0.4891 - val_loss: 0.5022 - val_acc: 0.5385
#
# Epoch 00070: val_acc did not improve
# Epoch 71/100
#  - 29s - loss: 0.5021 - acc: 0.5242 - val_loss: 0.5021 - val_acc: 0.5385
#
# Epoch 00071: val_acc did not improve
# Epoch 72/100
#  - 29s - loss: 0.5021 - acc: 0.5325 - val_loss: 0.5020 - val_acc: 0.5385
#
# Epoch 00072: val_acc did not improve
# Epoch 73/100
#  - 29s - loss: 0.5020 - acc: 0.4825 - val_loss: 0.5019 - val_acc: 0.5385
#
# Epoch 00073: val_acc did not improve
# Epoch 74/100
#  - 29s - loss: 0.5019 - acc: 0.5067 - val_loss: 0.5019 - val_acc: 0.4615
#
# Epoch 00074: val_acc did not improve
# Epoch 75/100
#  - 29s - loss: 0.5018 - acc: 0.4725 - val_loss: 0.5018 - val_acc: 0.4615
#
# Epoch 00075: val_acc did not improve
# Epoch 76/100
#  - 29s - loss: 0.5018 - acc: 0.5150 - val_loss: 0.5017 - val_acc: 0.5385
#
# Epoch 00076: val_acc did not improve
# Epoch 77/100
#  - 29s - loss: 0.5017 - acc: 0.5158 - val_loss: 0.5017 - val_acc: 0.5385
#
# Epoch 00077: val_acc did not improve
# Epoch 78/100
#  - 29s - loss: 0.5016 - acc: 0.4958 - val_loss: 0.5016 - val_acc: 0.5385
#
# Epoch 00078: val_acc did not improve
# Epoch 79/100
#  - 29s - loss: 0.5016 - acc: 0.5075 - val_loss: 0.5015 - val_acc: 0.4615
#
# Epoch 00079: val_acc did not improve
# Epoch 80/100
#  - 29s - loss: 0.5015 - acc: 0.5301 - val_loss: 0.5015 - val_acc: 0.5385
#
# Epoch 00080: val_acc did not improve
# Epoch 81/100
#  - 29s - loss: 0.5015 - acc: 0.5166 - val_loss: 0.5014 - val_acc: 0.5385
#
# Epoch 00081: val_acc did not improve
# Epoch 82/100
#  - 29s - loss: 0.5014 - acc: 0.5000 - val_loss: 0.5014 - val_acc: 0.4615
#
# Epoch 00082: val_acc did not improve
# Epoch 83/100
#  - 29s - loss: 0.5013 - acc: 0.4675 - val_loss: 0.5013 - val_acc: 0.4615
#
# Epoch 00083: val_acc did not improve
# Epoch 84/100
#  - 29s - loss: 0.5013 - acc: 0.5159 - val_loss: 0.5013 - val_acc: 0.4615
#
# Epoch 00084: val_acc did not improve
# Epoch 85/100
#  - 29s - loss: 0.5012 - acc: 0.4733 - val_loss: 0.5012 - val_acc: 0.4615
#
# Epoch 00085: val_acc did not improve
# Epoch 86/100
#  - 29s - loss: 0.5012 - acc: 0.5066 - val_loss: 0.5012 - val_acc: 0.4615
#
# Epoch 00086: val_acc did not improve
# Epoch 87/100
#  - 29s - loss: 0.5012 - acc: 0.5375 - val_loss: 0.5011 - val_acc: 0.5385
#
# Epoch 00087: val_acc did not improve
# Epoch 88/100
#  - 29s - loss: 0.5011 - acc: 0.4917 - val_loss: 0.5011 - val_acc: 0.4615
#
# Epoch 00088: val_acc did not improve
# Epoch 89/100
#  - 29s - loss: 0.5011 - acc: 0.4625 - val_loss: 0.5011 - val_acc: 0.4615
#
# Epoch 00089: val_acc did not improve
# Epoch 90/100
#  - 29s - loss: 0.5010 - acc: 0.4692 - val_loss: 0.5010 - val_acc: 0.4615
#
# Epoch 00090: val_acc did not improve
# Epoch 91/100
#  - 29s - loss: 0.5010 - acc: 0.4942 - val_loss: 0.5010 - val_acc: 0.4615
#
# Epoch 00091: val_acc did not improve
# Epoch 92/100
#  - 29s - loss: 0.5010 - acc: 0.4875 - val_loss: 0.5010 - val_acc: 0.5385
#
# Epoch 00092: val_acc did not improve
# Epoch 93/100
#  - 29s - loss: 0.5009 - acc: 0.4800 - val_loss: 0.5009 - val_acc: 0.4615
#
# Epoch 00093: val_acc did not improve
# Epoch 94/100
#  - 29s - loss: 0.5009 - acc: 0.5067 - val_loss: 0.5009 - val_acc: 0.4615
#
# Epoch 00094: val_acc did not improve
# Epoch 95/100
#  - 29s - loss: 0.5009 - acc: 0.4783 - val_loss: 0.5009 - val_acc: 0.4615
#
# Epoch 00095: val_acc did not improve
# Epoch 96/100
#  - 29s - loss: 0.5008 - acc: 0.5100 - val_loss: 0.5008 - val_acc: 0.4615
#
# Epoch 00096: val_acc did not improve
# Epoch 97/100
#  - 29s - loss: 0.5008 - acc: 0.4683 - val_loss: 0.5008 - val_acc: 0.4615
#
# Epoch 00097: val_acc did not improve
# Epoch 98/100
#  - 29s - loss: 0.5008 - acc: 0.5283 - val_loss: 0.5008 - val_acc: 0.5385
#
# Epoch 00098: val_acc did not improve
# Epoch 99/100
#  - 29s - loss: 0.5008 - acc: 0.5259 - val_loss: 0.5007 - val_acc: 0.4615
#
# Epoch 00099: val_acc did not improve
# Epoch 100/100
#  - 29s - loss: 0.5007 - acc: 0.5175 - val_loss: 0.5007 - val_acc: 0.4615
#
# Epoch 00100: val_acc did not improve

# %%
# plot history 
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc= 'upper left' )
plt.show()

# %%
# Save model 
model.save('forgecy_image_model.h5')
# model.summary()
# model.get_weights()
# model.optimizer
## Load  model 
#from keras.models import load_model 
#model = load_model('forgecy_image_model.h5')

# %%
# # estimate accuracy on whole dataset using loaded weights
# scores = model.evaluate(X, Y, verbose=0)
# print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

# %%
test_imgs, test_labels = next(test_batches)
test_labels = test_labels[:, 0]
predictions = model.predict_generator(test_batches, steps =1 , verbose = 0)
predictions
test_batches.class_indices
# rounded _predictions = model.predict_generator_classes(test_batches, steps =1 , verbose = 0)

# %%
cm = confusion_matrix(test_lables, np.round(predictions[:,0]))
cm_plot_labels = ['Au', 'Sp']
plot_confusion_matix(cm, cm_plot_labels, title = 'confusion Matrix')
